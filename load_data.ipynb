# %%
import pandas as pd
import os

# Read the label file and format the file name list
labels_df = pd.read_csv('labels.csv', header=0, names=['filename', 'label'])
labels_df['filename'] = labels_df['filename'].apply(lambda x: f'{x:04}')
labels_df['label'] = labels_df['label'].map({'OK': 1, 'NOK': 0}) # Convert labels to 0 and 1

# Convert labels_df to dictionary where filenames are keys and labels are values(0/1)
labels_dict = dict(zip(labels_df['filename'], labels_df['label']))
# print(labels_dict)

# %% [markdown]
# labels_dict :{'0025': 0, '0028': 1, '0031': 1, '0032': 0, '0036': 1, '0037': 1, ...}

# %%
# Create an empty dictionary to store all DataFrames
data_frames = {}

# Specify the directory containing the CSV file
data_directory = 'data/'

# Iterate through all files in a directory
# i = 0
for filename in os.listdir(data_directory):
    if filename.endswith('.csv'):
        # Remove file extension and get base name of file (e.g. 0025.csv -> 0025)
        base_filename = filename[:-4]

        # Read CSV file
        file_path = os.path.join(data_directory, filename)
        temp_df = pd.read_csv(file_path)
        # Extract seconds from time and convert them into a more manageable numerical form
        temp_df['time'] = pd.to_datetime(temp_df['time']) 
        temp_df['seconds'] = temp_df['time'].dt.second + temp_df['time'].dt.microsecond / 1e6 
        # i += 1
        # print(f"dataframe of {file_path} is read, it is the {i}th one")

        # Store DataFrame into dictionary
        data_frames[base_filename] = temp_df

# When you need to access to a specific file for example '0025.csv'
specific_filename = '0025'
print(data_frames['0025'].head())

# When you need to view the tag of a specific file
if specific_filename in labels_dict:
    specific_label = labels_dict[specific_filename]
    print(f"Label for file '{specific_filename}': {specific_label}")
# Out:
# dataframe of data/0025.csv is read, it is the 1th one
# dataframe of data/0028.csv is read, it is the 2th one
# dataframe of data/0031.csv is read, it is the 3th one
# dataframe of data/0032.csv is read, it is the 4th one
# dataframe of data/0036.csv is read, it is the 5th one
# dataframe of data/0037.csv is read, it is the 6th one
# dataframe of data/0041.csv is read, it is the 7th one
# dataframe of data/0055.csv is read, it is the 8th one
# dataframe of data/0079.csv is read, it is the 9th one
# dataframe of data/0097.csv is read, it is the 10th one
# dataframe of data/0100.csv is read, it is the 11th one
# dataframe of data/0103.csv is read, it is the 12th one
# dataframe of data/0105.csv is read, it is the 13th one
# dataframe of data/0108.csv is read, it is the 14th one
# dataframe of data/0109.csv is read, it is the 15th one
# dataframe of data/0123.csv is read, it is the 16th one
# dataframe of data/0124.csv is read, it is the 17th one
# dataframe of data/0129.csv is read, it is the 18th one
# dataframe of data/0134.csv is read, it is the 19th one
# dataframe of data/0157.csv is read, it is the 20th one
# dataframe of data/0164.csv is read, it is the 21th one
# dataframe of data/0173.csv is read, it is the 22th one
# dataframe of data/0199.csv is read, it is the 23th one
# dataframe of data/0204.csv is read, it is the 24th one
# dataframe of data/0205.csv is read, it is the 25th one
# dataframe of data/0211.csv is read, it is the 26th one
# dataframe of data/0224.csv is read, it is the 27th one
# dataframe of data/0227.csv is read, it is the 28th one
# dataframe of data/0228.csv is read, it is the 29th one
# dataframe of data/0234.csv is read, it is the 30th one
# dataframe of data/0236.csv is read, it is the 31th one
# dataframe of data/0239.csv is read, it is the 32th one
# dataframe of data/0247.csv is read, it is the 33th one
# dataframe of data/0249.csv is read, it is the 34th one
# dataframe of data/0250.csv is read, it is the 35th one
# dataframe of data/0252.csv is read, it is the 36th one
# dataframe of data/0274.csv is read, it is the 37th one
# dataframe of data/0279.csv is read, it is the 38th one
# dataframe of data/0281.csv is read, it is the 39th one
# dataframe of data/0286.csv is read, it is the 40th one
# dataframe of data/0298.csv is read, it is the 41th one
# dataframe of data/0301.csv is read, it is the 42th one
# dataframe of data/0305.csv is read, it is the 43th one
# dataframe of data/0316.csv is read, it is the 44th one
# dataframe of data/0318.csv is read, it is the 45th one
# dataframe of data/0324.csv is read, it is the 46th one
# dataframe of data/0342.csv is read, it is the 47th one
# dataframe of data/0367.csv is read, it is the 48th one
# dataframe of data/0369.csv is read, it is the 49th one
# dataframe of data/0373.csv is read, it is the 50th one
# dataframe of data/0382.csv is read, it is the 51th one
# dataframe of data/0385.csv is read, it is the 52th one
# dataframe of data/0400.csv is read, it is the 53th one
# dataframe of data/0404.csv is read, it is the 54th one
# dataframe of data/0411.csv is read, it is the 55th one
# dataframe of data/0419.csv is read, it is the 56th one
# dataframe of data/0421.csv is read, it is the 57th one
# dataframe of data/0422.csv is read, it is the 58th one
# dataframe of data/0425.csv is read, it is the 59th one
# dataframe of data/0426.csv is read, it is the 60th one
# dataframe of data/0428.csv is read, it is the 61th one
# dataframe of data/0429.csv is read, it is the 62th one
# dataframe of data/0431.csv is read, it is the 63th one
# dataframe of data/0438.csv is read, it is the 64th one
# dataframe of data/0440.csv is read, it is the 65th one
# dataframe of data/0450.csv is read, it is the 66th one
# dataframe of data/0460.csv is read, it is the 67th one
# dataframe of data/0469.csv is read, it is the 68th one
# dataframe of data/0470.csv is read, it is the 69th one
# dataframe of data/0474.csv is read, it is the 70th one
# dataframe of data/0475.csv is read, it is the 71th one
# dataframe of data/0490.csv is read, it is the 72th one
# dataframe of data/0494.csv is read, it is the 73th one
# dataframe of data/0499.csv is read, it is the 74th one
# dataframe of data/0501.csv is read, it is the 75th one
# dataframe of data/0502.csv is read, it is the 76th one
# dataframe of data/0508.csv is read, it is the 77th one
# dataframe of data/0509.csv is read, it is the 78th one
# dataframe of data/0527.csv is read, it is the 79th one
# dataframe of data/0528.csv is read, it is the 80th one
# dataframe of data/0530.csv is read, it is the 81th one
# dataframe of data/0540.csv is read, it is the 82th one
# dataframe of data/0544.csv is read, it is the 83th one
# dataframe of data/0557.csv is read, it is the 84th one
# dataframe of data/0564.csv is read, it is the 85th one
# dataframe of data/0567.csv is read, it is the 86th one
# dataframe of data/0571.csv is read, it is the 87th one
# dataframe of data/0581.csv is read, it is the 88th one
# dataframe of data/0583.csv is read, it is the 89th one
# dataframe of data/0601.csv is read, it is the 90th one
# dataframe of data/0611.csv is read, it is the 91th one
# dataframe of data/0615.csv is read, it is the 92th one
# dataframe of data/0619.csv is read, it is the 93th one
# dataframe of data/0627.csv is read, it is the 94th one
# dataframe of data/0661.csv is read, it is the 95th one
# dataframe of data/0666.csv is read, it is the 96th one
# dataframe of data/0673.csv is read, it is the 97th one
# dataframe of data/0674.csv is read, it is the 98th one
# dataframe of data/0677.csv is read, it is the 99th one
# dataframe of data/0679.csv is read, it is the 100th one
# dataframe of data/0686.csv is read, it is the 101th one
# dataframe of data/0688.csv is read, it is the 102th one
# dataframe of data/0692.csv is read, it is the 103th one
# dataframe of data/0703.csv is read, it is the 104th one
# dataframe of data/0711.csv is read, it is the 105th one
# dataframe of data/0719.csv is read, it is the 106th one
# dataframe of data/0729.csv is read, it is the 107th one
# dataframe of data/0733.csv is read, it is the 108th one
# dataframe of data/0734.csv is read, it is the 109th one
# dataframe of data/0743.csv is read, it is the 110th one
# dataframe of data/0747.csv is read, it is the 111th one
# dataframe of data/0748.csv is read, it is the 112th one
# dataframe of data/0751.csv is read, it is the 113th one
# dataframe of data/0752.csv is read, it is the 114th one
# dataframe of data/0755.csv is read, it is the 115th one
# dataframe of data/0756.csv is read, it is the 116th one
# dataframe of data/0769.csv is read, it is the 117th one
# dataframe of data/0777.csv is read, it is the 118th one
# dataframe of data/0783.csv is read, it is the 119th one
# dataframe of data/0799.csv is read, it is the 120th one
# dataframe of data/0802.csv is read, it is the 121th one
# dataframe of data/0807.csv is read, it is the 122th one
# dataframe of data/0813.csv is read, it is the 123th one
# dataframe of data/0815.csv is read, it is the 124th one
# dataframe of data/0818.csv is read, it is the 125th one
# dataframe of data/0824.csv is read, it is the 126th one
# dataframe of data/0834.csv is read, it is the 127th one
# dataframe of data/0845.csv is read, it is the 128th one
# dataframe of data/0848.csv is read, it is the 129th one
# dataframe of data/0858.csv is read, it is the 130th one
# dataframe of data/0867.csv is read, it is the 131th one
# dataframe of data/0882.csv is read, it is the 132th one
# dataframe of data/0911.csv is read, it is the 133th one
# dataframe of data/0912.csv is read, it is the 134th one
# dataframe of data/0918.csv is read, it is the 135th one
# dataframe of data/0919.csv is read, it is the 136th one
# dataframe of data/0920.csv is read, it is the 137th one
# dataframe of data/0924.csv is read, it is the 138th one
# dataframe of data/0933.csv is read, it is the 139th one
# dataframe of data/0950.csv is read, it is the 140th one
# dataframe of data/0956.csv is read, it is the 141th one
# dataframe of data/0961.csv is read, it is the 142th one
# dataframe of data/0963.csv is read, it is the 143th one
# dataframe of data/0965.csv is read, it is the 144th one
# dataframe of data/0983.csv is read, it is the 145th one
# dataframe of data/0989.csv is read, it is the 146th one
# dataframe of data/0992.csv is read, it is the 147th one
# dataframe of data/0993.csv is read, it is the 148th one
# dataframe of data/1020.csv is read, it is the 149th one
# dataframe of data/1025.csv is read, it is the 150th one
# dataframe of data/1035.csv is read, it is the 151th one
# dataframe of data/1048.csv is read, it is the 152th one
# dataframe of data/1051.csv is read, it is the 153th one
# dataframe of data/1065.csv is read, it is the 154th one
# dataframe of data/1073.csv is read, it is the 155th one
# dataframe of data/1076.csv is read, it is the 156th one
# dataframe of data/1078.csv is read, it is the 157th one
# dataframe of data/1079.csv is read, it is the 158th one
# dataframe of data/1085.csv is read, it is the 159th one
# dataframe of data/1089.csv is read, it is the 160th one
# dataframe of data/1093.csv is read, it is the 161th one
# dataframe of data/1100.csv is read, it is the 162th one
# dataframe of data/1102.csv is read, it is the 163th one
# dataframe of data/1107.csv is read, it is the 164th one
# dataframe of data/1123.csv is read, it is the 165th one
# dataframe of data/1131.csv is read, it is the 166th one
# dataframe of data/1140.csv is read, it is the 167th one
# dataframe of data/1142.csv is read, it is the 168th one
# dataframe of data/1146.csv is read, it is the 169th one
# dataframe of data/1149.csv is read, it is the 170th one
# dataframe of data/1152.csv is read, it is the 171th one
# dataframe of data/1162.csv is read, it is the 172th one
# dataframe of data/1163.csv is read, it is the 173th one
# dataframe of data/1164.csv is read, it is the 174th one
# dataframe of data/1168.csv is read, it is the 175th one
# dataframe of data/1173.csv is read, it is the 176th one
# dataframe of data/1174.csv is read, it is the 177th one
# dataframe of data/1206.csv is read, it is the 178th one
# dataframe of data/1214.csv is read, it is the 179th one
# dataframe of data/1218.csv is read, it is the 180th one
# dataframe of data/1224.csv is read, it is the 181th one
# dataframe of data/1251.csv is read, it is the 182th one
# dataframe of data/1265.csv is read, it is the 183th one
# dataframe of data/1281.csv is read, it is the 184th one
# dataframe of data/1284.csv is read, it is the 185th one
# dataframe of data/1287.csv is read, it is the 186th one
# dataframe of data/1292.csv is read, it is the 187th one
# dataframe of data/1308.csv is read, it is the 188th one
# dataframe of data/1321.csv is read, it is the 189th one
# dataframe of data/1325.csv is read, it is the 190th one
# dataframe of data/1339.csv is read, it is the 191th one
# dataframe of data/1348.csv is read, it is the 192th one
# dataframe of data/1351.csv is read, it is the 193th one
# dataframe of data/1352.csv is read, it is the 194th one
# dataframe of data/1353.csv is read, it is the 195th one
# dataframe of data/1354.csv is read, it is the 196th one
# dataframe of data/1356.csv is read, it is the 197th one
# dataframe of data/1363.csv is read, it is the 198th one
# dataframe of data/1371.csv is read, it is the 199th one
# dataframe of data/1373.csv is read, it is the 200th one
# dataframe of data/1374.csv is read, it is the 201th one
# dataframe of data/1378.csv is read, it is the 202th one
# dataframe of data/1381.csv is read, it is the 203th one
# dataframe of data/1382.csv is read, it is the 204th one
# dataframe of data/1385.csv is read, it is the 205th one
# dataframe of data/1387.csv is read, it is the 206th one
# dataframe of data/1390.csv is read, it is the 207th one
# dataframe of data/1395.csv is read, it is the 208th one
# dataframe of data/1409.csv is read, it is the 209th one
# dataframe of data/1411.csv is read, it is the 210th one
# dataframe of data/1421.csv is read, it is the 211th one
# dataframe of data/1425.csv is read, it is the 212th one
# dataframe of data/1426.csv is read, it is the 213th one
# dataframe of data/1444.csv is read, it is the 214th one
# dataframe of data/1446.csv is read, it is the 215th one
# dataframe of data/1448.csv is read, it is the 216th one
# dataframe of data/1450.csv is read, it is the 217th one
# dataframe of data/1452.csv is read, it is the 218th one
# dataframe of data/1456.csv is read, it is the 219th one
# dataframe of data/1460.csv is read, it is the 220th one
# dataframe of data/1463.csv is read, it is the 221th one
# dataframe of data/1465.csv is read, it is the 222th one
# dataframe of data/1477.csv is read, it is the 223th one
# dataframe of data/1479.csv is read, it is the 224th one
# dataframe of data/1481.csv is read, it is the 225th one
# dataframe of data/1487.csv is read, it is the 226th one
# dataframe of data/1494.csv is read, it is the 227th one
# dataframe of data/1500.csv is read, it is the 228th one
# dataframe of data/1502.csv is read, it is the 229th one
# dataframe of data/1508.csv is read, it is the 230th one
# dataframe of data/1510.csv is read, it is the 231th one
# dataframe of data/1514.csv is read, it is the 232th one
# dataframe of data/1524.csv is read, it is the 233th one
# dataframe of data/1529.csv is read, it is the 234th one
# dataframe of data/1539.csv is read, it is the 235th one
# dataframe of data/1543.csv is read, it is the 236th one
# dataframe of data/1549.csv is read, it is the 237th one
# dataframe of data/1552.csv is read, it is the 238th one
# dataframe of data/1571.csv is read, it is the 239th one
# dataframe of data/1572.csv is read, it is the 240th one
# dataframe of data/1575.csv is read, it is the 241th one
# dataframe of data/1581.csv is read, it is the 242th one
# dataframe of data/1587.csv is read, it is the 243th one
# dataframe of data/1588.csv is read, it is the 244th one
# dataframe of data/1595.csv is read, it is the 245th one
# dataframe of data/1598.csv is read, it is the 246th one
# dataframe of data/1602.csv is read, it is the 247th one
# dataframe of data/1603.csv is read, it is the 248th one
# dataframe of data/1605.csv is read, it is the 249th one
# dataframe of data/1614.csv is read, it is the 250th one
# dataframe of data/1616.csv is read, it is the 251th one
# dataframe of data/1622.csv is read, it is the 252th one
# dataframe of data/1624.csv is read, it is the 253th one
# dataframe of data/1630.csv is read, it is the 254th one
# dataframe of data/1635.csv is read, it is the 255th one
# dataframe of data/1642.csv is read, it is the 256th one
# dataframe of data/1660.csv is read, it is the 257th one
# dataframe of data/1673.csv is read, it is the 258th one
# dataframe of data/1681.csv is read, it is the 259th one
# dataframe of data/1687.csv is read, it is the 260th one
# dataframe of data/1688.csv is read, it is the 261th one
# dataframe of data/1714.csv is read, it is the 262th one
# dataframe of data/1724.csv is read, it is the 263th one
# dataframe of data/1734.csv is read, it is the 264th one
# dataframe of data/1741.csv is read, it is the 265th one
# dataframe of data/1744.csv is read, it is the 266th one
# dataframe of data/1755.csv is read, it is the 267th one
# dataframe of data/1762.csv is read, it is the 268th one
# dataframe of data/1765.csv is read, it is the 269th one
# dataframe of data/1795.csv is read, it is the 270th one
# dataframe of data/1803.csv is read, it is the 271th one
# dataframe of data/1807.csv is read, it is the 272th one
# dataframe of data/1808.csv is read, it is the 273th one
# dataframe of data/1811.csv is read, it is the 274th one
# dataframe of data/1812.csv is read, it is the 275th one
# dataframe of data/1819.csv is read, it is the 276th one
# dataframe of data/1822.csv is read, it is the 277th one
# dataframe of data/1826.csv is read, it is the 278th one
# dataframe of data/1830.csv is read, it is the 279th one
# dataframe of data/1832.csv is read, it is the 280th one
# dataframe of data/1833.csv is read, it is the 281th one
# dataframe of data/1837.csv is read, it is the 282th one
# dataframe of data/1842.csv is read, it is the 283th one
# dataframe of data/1850.csv is read, it is the 284th one
# dataframe of data/1852.csv is read, it is the 285th one
# dataframe of data/1856.csv is read, it is the 286th one
# dataframe of data/1876.csv is read, it is the 287th one
# dataframe of data/1879.csv is read, it is the 288th one
# dataframe of data/1889.csv is read, it is the 289th one
# dataframe of data/1892.csv is read, it is the 290th one
# dataframe of data/1905.csv is read, it is the 291th one
# dataframe of data/1911.csv is read, it is the 292th one
# dataframe of data/1915.csv is read, it is the 293th one
# dataframe of data/1923.csv is read, it is the 294th one
# dataframe of data/1924.csv is read, it is the 295th one
# dataframe of data/1931.csv is read, it is the 296th one
# dataframe of data/1944.csv is read, it is the 297th one
# dataframe of data/1950.csv is read, it is the 298th one
# dataframe of data/1952.csv is read, it is the 299th one
# dataframe of data/1970.csv is read, it is the 300th one
# dataframe of data/1971.csv is read, it is the 301th one
# dataframe of data/2028.csv is read, it is the 302th one
# dataframe of data/2037.csv is read, it is the 303th one
# dataframe of data/2042.csv is read, it is the 304th one
# dataframe of data/2043.csv is read, it is the 305th one
# dataframe of data/2045.csv is read, it is the 306th one
# dataframe of data/2047.csv is read, it is the 307th one
# dataframe of data/2053.csv is read, it is the 308th one
# dataframe of data/2066.csv is read, it is the 309th one
# dataframe of data/2068.csv is read, it is the 310th one
# dataframe of data/2076.csv is read, it is the 311th one
# dataframe of data/2084.csv is read, it is the 312th one
# dataframe of data/2086.csv is read, it is the 313th one
# dataframe of data/2091.csv is read, it is the 314th one
# dataframe of data/2111.csv is read, it is the 315th one
# dataframe of data/2113.csv is read, it is the 316th one
# dataframe of data/2127.csv is read, it is the 317th one
# dataframe of data/2133.csv is read, it is the 318th one
# dataframe of data/2140.csv is read, it is the 319th one
# dataframe of data/2144.csv is read, it is the 320th one
# dataframe of data/2146.csv is read, it is the 321th one
# dataframe of data/2147.csv is read, it is the 322th one
# dataframe of data/2149.csv is read, it is the 323th one
# dataframe of data/2162.csv is read, it is the 324th one
# dataframe of data/2163.csv is read, it is the 325th one
# dataframe of data/2166.csv is read, it is the 326th one
# dataframe of data/2170.csv is read, it is the 327th one
# dataframe of data/2175.csv is read, it is the 328th one
# dataframe of data/2176.csv is read, it is the 329th one
# dataframe of data/2190.csv is read, it is the 330th one
# dataframe of data/2197.csv is read, it is the 331th one
# dataframe of data/2199.csv is read, it is the 332th one
# dataframe of data/2209.csv is read, it is the 333th one
# dataframe of data/2214.csv is read, it is the 334th one
# dataframe of data/2223.csv is read, it is the 335th one
# dataframe of data/2235.csv is read, it is the 336th one
# dataframe of data/2241.csv is read, it is the 337th one
# dataframe of data/2252.csv is read, it is the 338th one
# dataframe of data/2254.csv is read, it is the 339th one
# dataframe of data/2269.csv is read, it is the 340th one
# dataframe of data/2274.csv is read, it is the 341th one
# dataframe of data/2279.csv is read, it is the 342th one
# dataframe of data/2314.csv is read, it is the 343th one
# dataframe of data/2318.csv is read, it is the 344th one
# dataframe of data/2320.csv is read, it is the 345th one
# dataframe of data/2329.csv is read, it is the 346th one
# dataframe of data/2337.csv is read, it is the 347th one
# dataframe of data/2341.csv is read, it is the 348th one
# dataframe of data/2350.csv is read, it is the 349th one
# dataframe of data/2353.csv is read, it is the 350th one
# dataframe of data/2357.csv is read, it is the 351th one
# dataframe of data/2358.csv is read, it is the 352th one
# dataframe of data/2360.csv is read, it is the 353th one
# dataframe of data/2383.csv is read, it is the 354th one
# dataframe of data/2384.csv is read, it is the 355th one
# dataframe of data/2388.csv is read, it is the 356th one
# dataframe of data/2396.csv is read, it is the 357th one
# dataframe of data/2398.csv is read, it is the 358th one
# dataframe of data/2406.csv is read, it is the 359th one
# dataframe of data/2424.csv is read, it is the 360th one
# dataframe of data/2428.csv is read, it is the 361th one
# dataframe of data/2431.csv is read, it is the 362th one
# dataframe of data/2432.csv is read, it is the 363th one
# dataframe of data/2451.csv is read, it is the 364th one
# dataframe of data/2471.csv is read, it is the 365th one
# dataframe of data/2478.csv is read, it is the 366th one
# dataframe of data/2486.csv is read, it is the 367th one
# dataframe of data/2490.csv is read, it is the 368th one
# dataframe of data/2495.csv is read, it is the 369th one
# dataframe of data/2504.csv is read, it is the 370th one
# dataframe of data/2509.csv is read, it is the 371th one
# dataframe of data/2514.csv is read, it is the 372th one
# dataframe of data/2519.csv is read, it is the 373th one
# dataframe of data/2523.csv is read, it is the 374th one
# dataframe of data/2531.csv is read, it is the 375th one
# dataframe of data/2539.csv is read, it is the 376th one
# dataframe of data/2541.csv is read, it is the 377th one
# dataframe of data/2544.csv is read, it is the 378th one
# dataframe of data/2547.csv is read, it is the 379th one
# dataframe of data/2550.csv is read, it is the 380th one
# dataframe of data/2561.csv is read, it is the 381th one
# dataframe of data/2563.csv is read, it is the 382th one
# dataframe of data/2572.csv is read, it is the 383th one
# dataframe of data/2589.csv is read, it is the 384th one
# dataframe of data/2590.csv is read, it is the 385th one
# dataframe of data/2598.csv is read, it is the 386th one
# dataframe of data/2620.csv is read, it is the 387th one
# dataframe of data/2622.csv is read, it is the 388th one
# dataframe of data/2628.csv is read, it is the 389th one
# dataframe of data/2665.csv is read, it is the 390th one
# dataframe of data/2666.csv is read, it is the 391th one
# dataframe of data/2670.csv is read, it is the 392th one
# dataframe of data/2676.csv is read, it is the 393th one
# dataframe of data/2682.csv is read, it is the 394th one
# dataframe of data/2684.csv is read, it is the 395th one
# dataframe of data/2688.csv is read, it is the 396th one
# dataframe of data/2691.csv is read, it is the 397th one
# dataframe of data/2700.csv is read, it is the 398th one
# dataframe of data/2701.csv is read, it is the 399th one
# dataframe of data/2739.csv is read, it is the 400th one
# dataframe of data/2741.csv is read, it is the 401th one
# dataframe of data/2753.csv is read, it is the 402th one
# dataframe of data/2756.csv is read, it is the 403th one
# dataframe of data/2762.csv is read, it is the 404th one
# dataframe of data/2766.csv is read, it is the 405th one
# dataframe of data/2770.csv is read, it is the 406th one
# dataframe of data/2771.csv is read, it is the 407th one
# dataframe of data/2772.csv is read, it is the 408th one
# dataframe of data/2775.csv is read, it is the 409th one
# dataframe of data/2776.csv is read, it is the 410th one
# dataframe of data/2783.csv is read, it is the 411th one
# dataframe of data/2785.csv is read, it is the 412th one
# dataframe of data/2788.csv is read, it is the 413th one
# dataframe of data/2816.csv is read, it is the 414th one
# dataframe of data/2817.csv is read, it is the 415th one
# dataframe of data/2821.csv is read, it is the 416th one
# dataframe of data/2825.csv is read, it is the 417th one
# dataframe of data/2827.csv is read, it is the 418th one
# dataframe of data/2846.csv is read, it is the 419th one
# dataframe of data/2849.csv is read, it is the 420th one
# dataframe of data/2858.csv is read, it is the 421th one
# dataframe of data/2862.csv is read, it is the 422th one
# dataframe of data/2871.csv is read, it is the 423th one
# dataframe of data/2875.csv is read, it is the 424th one
# dataframe of data/2876.csv is read, it is the 425th one
# dataframe of data/2878.csv is read, it is the 426th one
# dataframe of data/2886.csv is read, it is the 427th one
# dataframe of data/2888.csv is read, it is the 428th one
# dataframe of data/2906.csv is read, it is the 429th one
# dataframe of data/2915.csv is read, it is the 430th one
# dataframe of data/2922.csv is read, it is the 431th one
# dataframe of data/2923.csv is read, it is the 432th one
# dataframe of data/2933.csv is read, it is the 433th one
# dataframe of data/2934.csv is read, it is the 434th one
# dataframe of data/2941.csv is read, it is the 435th one
# dataframe of data/2944.csv is read, it is the 436th one
# dataframe of data/2946.csv is read, it is the 437th one
# dataframe of data/2951.csv is read, it is the 438th one
# dataframe of data/2953.csv is read, it is the 439th one
# dataframe of data/2966.csv is read, it is the 440th one
# dataframe of data/2969.csv is read, it is the 441th one
# dataframe of data/2971.csv is read, it is the 442th one
# dataframe of data/2974.csv is read, it is the 443th one
# dataframe of data/2978.csv is read, it is the 444th one
# dataframe of data/2980.csv is read, it is the 445th one
# dataframe of data/2985.csv is read, it is the 446th one
# dataframe of data/3001.csv is read, it is the 447th one
# dataframe of data/3024.csv is read, it is the 448th one
# dataframe of data/3037.csv is read, it is the 449th one
# dataframe of data/3040.csv is read, it is the 450th one
# dataframe of data/3052.csv is read, it is the 451th one
# dataframe of data/3055.csv is read, it is the 452th one
# dataframe of data/3056.csv is read, it is the 453th one
# dataframe of data/3067.csv is read, it is the 454th one
# dataframe of data/3073.csv is read, it is the 455th one
# dataframe of data/3074.csv is read, it is the 456th one
# dataframe of data/3083.csv is read, it is the 457th one
# dataframe of data/3095.csv is read, it is the 458th one
# dataframe of data/3098.csv is read, it is the 459th one
# dataframe of data/3102.csv is read, it is the 460th one
# dataframe of data/3105.csv is read, it is the 461th one
# dataframe of data/3112.csv is read, it is the 462th one
# dataframe of data/3113.csv is read, it is the 463th one
# dataframe of data/3114.csv is read, it is the 464th one
# dataframe of data/3116.csv is read, it is the 465th one
# dataframe of data/3118.csv is read, it is the 466th one
# dataframe of data/3121.csv is read, it is the 467th one
# dataframe of data/3125.csv is read, it is the 468th one
# dataframe of data/3133.csv is read, it is the 469th one
# dataframe of data/3144.csv is read, it is the 470th one
# dataframe of data/3155.csv is read, it is the 471th one
# dataframe of data/3167.csv is read, it is the 472th one
# dataframe of data/3182.csv is read, it is the 473th one
# dataframe of data/3183.csv is read, it is the 474th one
# dataframe of data/3186.csv is read, it is the 475th one
# dataframe of data/3203.csv is read, it is the 476th one
# dataframe of data/3205.csv is read, it is the 477th one
# dataframe of data/3210.csv is read, it is the 478th one
# dataframe of data/3212.csv is read, it is the 479th one
# dataframe of data/3222.csv is read, it is the 480th one
# dataframe of data/3234.csv is read, it is the 481th one
# dataframe of data/3236.csv is read, it is the 482th one
# dataframe of data/3237.csv is read, it is the 483th one
# dataframe of data/3253.csv is read, it is the 484th one
# dataframe of data/3257.csv is read, it is the 485th one
# dataframe of data/3260.csv is read, it is the 486th one
# dataframe of data/3284.csv is read, it is the 487th one
# dataframe of data/3287.csv is read, it is the 488th one
# dataframe of data/3288.csv is read, it is the 489th one
# dataframe of data/3304.csv is read, it is the 490th one
# dataframe of data/3307.csv is read, it is the 491th one
# dataframe of data/3315.csv is read, it is the 492th one
# dataframe of data/3347.csv is read, it is the 493th one
# dataframe of data/3356.csv is read, it is the 494th one
# dataframe of data/3365.csv is read, it is the 495th one
# dataframe of data/3373.csv is read, it is the 496th one
# dataframe of data/3379.csv is read, it is the 497th one
# dataframe of data/3391.csv is read, it is the 498th one
# dataframe of data/3393.csv is read, it is the 499th one
# dataframe of data/3397.csv is read, it is the 500th one
# dataframe of data/3398.csv is read, it is the 501th one
# dataframe of data/3401.csv is read, it is the 502th one
# dataframe of data/3406.csv is read, it is the 503th one
# dataframe of data/3455.csv is read, it is the 504th one
# dataframe of data/3458.csv is read, it is the 505th one
# dataframe of data/3466.csv is read, it is the 506th one
# dataframe of data/3483.csv is read, it is the 507th one
# dataframe of data/3486.csv is read, it is the 508th one
# dataframe of data/3488.csv is read, it is the 509th one
# dataframe of data/3502.csv is read, it is the 510th one
# dataframe of data/3509.csv is read, it is the 511th one
# dataframe of data/3511.csv is read, it is the 512th one
# dataframe of data/3520.csv is read, it is the 513th one
# dataframe of data/3524.csv is read, it is the 514th one
# dataframe of data/3535.csv is read, it is the 515th one
# dataframe of data/3540.csv is read, it is the 516th one
# dataframe of data/3543.csv is read, it is the 517th one
# dataframe of data/3545.csv is read, it is the 518th one
# dataframe of data/3555.csv is read, it is the 519th one
# dataframe of data/3559.csv is read, it is the 520th one
# dataframe of data/3567.csv is read, it is the 521th one
# dataframe of data/3587.csv is read, it is the 522th one
# dataframe of data/3592.csv is read, it is the 523th one
# dataframe of data/3604.csv is read, it is the 524th one
# dataframe of data/3621.csv is read, it is the 525th one
# dataframe of data/3625.csv is read, it is the 526th one
# dataframe of data/3632.csv is read, it is the 527th one
# dataframe of data/3636.csv is read, it is the 528th one
# dataframe of data/3638.csv is read, it is the 529th one
# dataframe of data/3652.csv is read, it is the 530th one
# dataframe of data/3668.csv is read, it is the 531th one
# dataframe of data/3673.csv is read, it is the 532th one
# dataframe of data/3676.csv is read, it is the 533th one
# dataframe of data/3678.csv is read, it is the 534th one
# dataframe of data/3684.csv is read, it is the 535th one
# dataframe of data/3686.csv is read, it is the 536th one
# dataframe of data/3687.csv is read, it is the 537th one
# dataframe of data/3692.csv is read, it is the 538th one
# dataframe of data/3693.csv is read, it is the 539th one
# dataframe of data/3706.csv is read, it is the 540th one
# dataframe of data/3710.csv is read, it is the 541th one
# dataframe of data/3720.csv is read, it is the 542th one
# dataframe of data/3721.csv is read, it is the 543th one
# dataframe of data/3735.csv is read, it is the 544th one
# dataframe of data/3738.csv is read, it is the 545th one
# dataframe of data/3740.csv is read, it is the 546th one
# dataframe of data/3741.csv is read, it is the 547th one
# dataframe of data/3748.csv is read, it is the 548th one
# dataframe of data/3755.csv is read, it is the 549th one
# dataframe of data/3757.csv is read, it is the 550th one
# dataframe of data/3787.csv is read, it is the 551th one
# dataframe of data/3797.csv is read, it is the 552th one
# dataframe of data/3806.csv is read, it is the 553th one
# dataframe of data/3809.csv is read, it is the 554th one
# dataframe of data/3817.csv is read, it is the 555th one
# dataframe of data/3822.csv is read, it is the 556th one
# dataframe of data/3828.csv is read, it is the 557th one
# dataframe of data/3830.csv is read, it is the 558th one
# dataframe of data/3833.csv is read, it is the 559th one
# dataframe of data/3837.csv is read, it is the 560th one
# dataframe of data/3838.csv is read, it is the 561th one
# dataframe of data/3841.csv is read, it is the 562th one
# dataframe of data/3842.csv is read, it is the 563th one
# dataframe of data/3843.csv is read, it is the 564th one
# dataframe of data/3858.csv is read, it is the 565th one
# dataframe of data/3861.csv is read, it is the 566th one
# dataframe of data/3870.csv is read, it is the 567th one
# dataframe of data/3871.csv is read, it is the 568th one
# dataframe of data/3872.csv is read, it is the 569th one
# dataframe of data/3874.csv is read, it is the 570th one
# dataframe of data/3880.csv is read, it is the 571th one
# dataframe of data/3888.csv is read, it is the 572th one
# dataframe of data/3895.csv is read, it is the 573th one
# dataframe of data/3901.csv is read, it is the 574th one
# dataframe of data/3903.csv is read, it is the 575th one
# dataframe of data/3907.csv is read, it is the 576th one
# dataframe of data/3927.csv is read, it is the 577th one
# dataframe of data/3929.csv is read, it is the 578th one
# dataframe of data/3938.csv is read, it is the 579th one
# dataframe of data/3948.csv is read, it is the 580th one
# dataframe of data/3956.csv is read, it is the 581th one
# dataframe of data/3957.csv is read, it is the 582th one
# dataframe of data/3963.csv is read, it is the 583th one
# dataframe of data/3971.csv is read, it is the 584th one
# dataframe of data/3974.csv is read, it is the 585th one
# dataframe of data/3977.csv is read, it is the 586th one
# dataframe of data/3981.csv is read, it is the 587th one
# dataframe of data/3996.csv is read, it is the 588th one
# dataframe of data/4002.csv is read, it is the 589th one
# dataframe of data/4015.csv is read, it is the 590th one
# dataframe of data/4017.csv is read, it is the 591th one
# dataframe of data/4021.csv is read, it is the 592th one
# dataframe of data/4023.csv is read, it is the 593th one
# dataframe of data/4059.csv is read, it is the 594th one
# dataframe of data/4062.csv is read, it is the 595th one
# dataframe of data/4070.csv is read, it is the 596th one
# dataframe of data/4071.csv is read, it is the 597th one
# dataframe of data/4072.csv is read, it is the 598th one
# dataframe of data/4075.csv is read, it is the 599th one
# dataframe of data/4078.csv is read, it is the 600th one
# dataframe of data/4080.csv is read, it is the 601th one
# dataframe of data/4082.csv is read, it is the 602th one
# dataframe of data/4085.csv is read, it is the 603th one
# dataframe of data/4094.csv is read, it is the 604th one
# dataframe of data/4099.csv is read, it is the 605th one
# dataframe of data/4103.csv is read, it is the 606th one
# dataframe of data/4114.csv is read, it is the 607th one
# dataframe of data/4115.csv is read, it is the 608th one
# dataframe of data/4122.csv is read, it is the 609th one
# dataframe of data/4123.csv is read, it is the 610th one
# dataframe of data/4124.csv is read, it is the 611th one
# dataframe of data/4133.csv is read, it is the 612th one
# dataframe of data/4141.csv is read, it is the 613th one
# dataframe of data/4142.csv is read, it is the 614th one
# dataframe of data/4143.csv is read, it is the 615th one
# dataframe of data/4144.csv is read, it is the 616th one
# dataframe of data/4146.csv is read, it is the 617th one
# dataframe of data/4149.csv is read, it is the 618th one
# dataframe of data/4157.csv is read, it is the 619th one
# dataframe of data/4165.csv is read, it is the 620th one
# dataframe of data/4168.csv is read, it is the 621th one
# dataframe of data/4171.csv is read, it is the 622th one
# dataframe of data/4172.csv is read, it is the 623th one
# dataframe of data/4173.csv is read, it is the 624th one
# dataframe of data/4180.csv is read, it is the 625th one
# dataframe of data/4189.csv is read, it is the 626th one
# dataframe of data/4190.csv is read, it is the 627th one
# dataframe of data/4197.csv is read, it is the 628th one
# dataframe of data/4200.csv is read, it is the 629th one
# dataframe of data/4201.csv is read, it is the 630th one
# dataframe of data/4203.csv is read, it is the 631th one
# dataframe of data/4207.csv is read, it is the 632th one
# dataframe of data/4214.csv is read, it is the 633th one
# dataframe of data/4223.csv is read, it is the 634th one
# dataframe of data/4235.csv is read, it is the 635th one
# dataframe of data/4239.csv is read, it is the 636th one
# dataframe of data/4242.csv is read, it is the 637th one
# dataframe of data/4244.csv is read, it is the 638th one
# dataframe of data/4262.csv is read, it is the 639th one
# dataframe of data/4270.csv is read, it is the 640th one
# dataframe of data/4273.csv is read, it is the 641th one
# dataframe of data/4276.csv is read, it is the 642th one
# dataframe of data/4279.csv is read, it is the 643th one
# dataframe of data/4280.csv is read, it is the 644th one
# dataframe of data/4281.csv is read, it is the 645th one
# dataframe of data/4294.csv is read, it is the 646th one
# dataframe of data/4299.csv is read, it is the 647th one
# dataframe of data/4304.csv is read, it is the 648th one
# dataframe of data/4305.csv is read, it is the 649th one
# dataframe of data/4313.csv is read, it is the 650th one
# dataframe of data/4315.csv is read, it is the 651th one
# dataframe of data/4318.csv is read, it is the 652th one
# dataframe of data/4321.csv is read, it is the 653th one
# dataframe of data/4326.csv is read, it is the 654th one
# dataframe of data/4329.csv is read, it is the 655th one
# dataframe of data/4335.csv is read, it is the 656th one
# dataframe of data/4341.csv is read, it is the 657th one
# dataframe of data/4343.csv is read, it is the 658th one
# dataframe of data/4346.csv is read, it is the 659th one
# dataframe of data/4360.csv is read, it is the 660th one
# dataframe of data/4362.csv is read, it is the 661th one
# dataframe of data/4366.csv is read, it is the 662th one
# dataframe of data/4369.csv is read, it is the 663th one
# dataframe of data/4376.csv is read, it is the 664th one
# dataframe of data/4399.csv is read, it is the 665th one
# dataframe of data/4413.csv is read, it is the 666th one
# dataframe of data/4414.csv is read, it is the 667th one
# dataframe of data/4422.csv is read, it is the 668th one
# dataframe of data/4423.csv is read, it is the 669th one
# dataframe of data/4431.csv is read, it is the 670th one
# dataframe of data/4432.csv is read, it is the 671th one
# dataframe of data/4434.csv is read, it is the 672th one
# dataframe of data/4442.csv is read, it is the 673th one
# dataframe of data/4449.csv is read, it is the 674th one
# dataframe of data/4451.csv is read, it is the 675th one
# dataframe of data/4454.csv is read, it is the 676th one
# dataframe of data/4463.csv is read, it is the 677th one
# dataframe of data/4465.csv is read, it is the 678th one
# dataframe of data/4470.csv is read, it is the 679th one
# dataframe of data/4472.csv is read, it is the 680th one
# dataframe of data/4474.csv is read, it is the 681th one
# dataframe of data/4486.csv is read, it is the 682th one
# dataframe of data/4495.csv is read, it is the 683th one
# dataframe of data/4498.csv is read, it is the 684th one
# dataframe of data/4501.csv is read, it is the 685th one
# dataframe of data/4503.csv is read, it is the 686th one
# dataframe of data/4507.csv is read, it is the 687th one
# dataframe of data/4516.csv is read, it is the 688th one
# dataframe of data/4517.csv is read, it is the 689th one
# dataframe of data/4519.csv is read, it is the 690th one
# dataframe of data/4528.csv is read, it is the 691th one
# dataframe of data/4533.csv is read, it is the 692th one
# dataframe of data/4538.csv is read, it is the 693th one
# dataframe of data/4543.csv is read, it is the 694th one
# dataframe of data/4545.csv is read, it is the 695th one
# dataframe of data/4555.csv is read, it is the 696th one
# dataframe of data/4560.csv is read, it is the 697th one
# dataframe of data/4575.csv is read, it is the 698th one
# dataframe of data/4581.csv is read, it is the 699th one
# dataframe of data/4598.csv is read, it is the 700th one
# dataframe of data/4601.csv is read, it is the 701th one
# dataframe of data/4610.csv is read, it is the 702th one
# dataframe of data/4623.csv is read, it is the 703th one
# dataframe of data/4628.csv is read, it is the 704th one
# dataframe of data/4644.csv is read, it is the 705th one
# dataframe of data/4650.csv is read, it is the 706th one
# dataframe of data/4668.csv is read, it is the 707th one
# dataframe of data/4670.csv is read, it is the 708th one
# dataframe of data/4671.csv is read, it is the 709th one
# dataframe of data/4679.csv is read, it is the 710th one
# dataframe of data/4689.csv is read, it is the 711th one
# dataframe of data/4694.csv is read, it is the 712th one
# dataframe of data/4701.csv is read, it is the 713th one
# dataframe of data/4704.csv is read, it is the 714th one
# dataframe of data/4707.csv is read, it is the 715th one
# dataframe of data/4710.csv is read, it is the 716th one
# dataframe of data/4720.csv is read, it is the 717th one
# dataframe of data/4728.csv is read, it is the 718th one
# dataframe of data/4730.csv is read, it is the 719th one
# dataframe of data/4735.csv is read, it is the 720th one
# dataframe of data/4737.csv is read, it is the 721th one
# dataframe of data/4741.csv is read, it is the 722th one
# dataframe of data/4746.csv is read, it is the 723th one
# dataframe of data/4751.csv is read, it is the 724th one
# dataframe of data/4754.csv is read, it is the 725th one
# dataframe of data/4758.csv is read, it is the 726th one
# dataframe of data/4761.csv is read, it is the 727th one
# dataframe of data/4765.csv is read, it is the 728th one
# dataframe of data/4770.csv is read, it is the 729th one
# dataframe of data/4772.csv is read, it is the 730th one
# dataframe of data/4773.csv is read, it is the 731th one
# dataframe of data/4774.csv is read, it is the 732th one
# dataframe of data/4780.csv is read, it is the 733th one
# dataframe of data/4786.csv is read, it is the 734th one
# dataframe of data/4787.csv is read, it is the 735th one
# dataframe of data/4791.csv is read, it is the 736th one
# dataframe of data/4798.csv is read, it is the 737th one
# dataframe of data/4804.csv is read, it is the 738th one
# dataframe of data/4805.csv is read, it is the 739th one
# dataframe of data/4808.csv is read, it is the 740th one
# dataframe of data/4811.csv is read, it is the 741th one
# dataframe of data/4812.csv is read, it is the 742th one
# dataframe of data/4814.csv is read, it is the 743th one
# dataframe of data/4815.csv is read, it is the 744th one
# dataframe of data/4819.csv is read, it is the 745th one
# dataframe of data/4821.csv is read, it is the 746th one
# dataframe of data/4824.csv is read, it is the 747th one
# dataframe of data/4838.csv is read, it is the 748th one
# dataframe of data/4839.csv is read, it is the 749th one
# dataframe of data/4840.csv is read, it is the 750th one
# dataframe of data/4843.csv is read, it is the 751th one
# dataframe of data/4845.csv is read, it is the 752th one
# dataframe of data/4848.csv is read, it is the 753th one
# dataframe of data/4853.csv is read, it is the 754th one
# dataframe of data/4859.csv is read, it is the 755th one
# dataframe of data/4860.csv is read, it is the 756th one
# dataframe of data/4865.csv is read, it is the 757th one
# dataframe of data/4872.csv is read, it is the 758th one
# dataframe of data/4882.csv is read, it is the 759th one
# dataframe of data/4896.csv is read, it is the 760th one
# dataframe of data/4910.csv is read, it is the 761th one
# dataframe of data/4923.csv is read, it is the 762th one
# dataframe of data/4931.csv is read, it is the 763th one
# dataframe of data/4945.csv is read, it is the 764th one
# dataframe of data/4950.csv is read, it is the 765th one
# dataframe of data/4956.csv is read, it is the 766th one
# dataframe of data/4959.csv is read, it is the 767th one
# dataframe of data/4974.csv is read, it is the 768th one
# dataframe of data/4975.csv is read, it is the 769th one
# dataframe of data/4976.csv is read, it is the 770th one
# dataframe of data/4979.csv is read, it is the 771th one
# dataframe of data/4980.csv is read, it is the 772th one
# dataframe of data/4981.csv is read, it is the 773th one
# dataframe of data/4982.csv is read, it is the 774th one
# dataframe of data/4994.csv is read, it is the 775th one
# dataframe of data/5000.csv is read, it is the 776th one
# dataframe of data/5003.csv is read, it is the 777th one
# dataframe of data/5014.csv is read, it is the 778th one
# dataframe of data/5020.csv is read, it is the 779th one
# dataframe of data/5025.csv is read, it is the 780th one
# dataframe of data/5049.csv is read, it is the 781th one
# dataframe of data/5053.csv is read, it is the 782th one
# dataframe of data/5054.csv is read, it is the 783th one
# dataframe of data/5067.csv is read, it is the 784th one
# dataframe of data/5077.csv is read, it is the 785th one
# dataframe of data/5102.csv is read, it is the 786th one
# dataframe of data/5104.csv is read, it is the 787th one
# dataframe of data/5107.csv is read, it is the 788th one
# dataframe of data/5110.csv is read, it is the 789th one
# dataframe of data/5113.csv is read, it is the 790th one
# dataframe of data/5124.csv is read, it is the 791th one
# dataframe of data/5128.csv is read, it is the 792th one
# dataframe of data/5137.csv is read, it is the 793th one
# dataframe of data/5139.csv is read, it is the 794th one
# dataframe of data/5142.csv is read, it is the 795th one
# dataframe of data/5146.csv is read, it is the 796th one
# dataframe of data/5149.csv is read, it is the 797th one
# dataframe of data/5150.csv is read, it is the 798th one
# dataframe of data/5151.csv is read, it is the 799th one
# dataframe of data/5163.csv is read, it is the 800th one
# dataframe of data/5169.csv is read, it is the 801th one
# dataframe of data/5175.csv is read, it is the 802th one
# dataframe of data/5184.csv is read, it is the 803th one
# dataframe of data/5189.csv is read, it is the 804th one
# dataframe of data/5197.csv is read, it is the 805th one
# dataframe of data/5198.csv is read, it is the 806th one
# dataframe of data/5200.csv is read, it is the 807th one
# dataframe of data/5207.csv is read, it is the 808th one
# dataframe of data/5210.csv is read, it is the 809th one
# dataframe of data/5213.csv is read, it is the 810th one
# dataframe of data/5229.csv is read, it is the 811th one
# dataframe of data/5232.csv is read, it is the 812th one
# dataframe of data/5237.csv is read, it is the 813th one
# dataframe of data/5241.csv is read, it is the 814th one
# dataframe of data/5244.csv is read, it is the 815th one
# dataframe of data/5246.csv is read, it is the 816th one
# dataframe of data/5254.csv is read, it is the 817th one
# dataframe of data/5267.csv is read, it is the 818th one
# dataframe of data/5278.csv is read, it is the 819th one
# dataframe of data/5289.csv is read, it is the 820th one
# dataframe of data/5295.csv is read, it is the 821th one
# dataframe of data/5306.csv is read, it is the 822th one
# dataframe of data/5316.csv is read, it is the 823th one
# dataframe of data/5327.csv is read, it is the 824th one
# dataframe of data/5328.csv is read, it is the 825th one
# dataframe of data/5339.csv is read, it is the 826th one
# dataframe of data/5341.csv is read, it is the 827th one
# dataframe of data/5346.csv is read, it is the 828th one
# dataframe of data/5354.csv is read, it is the 829th one
# dataframe of data/5356.csv is read, it is the 830th one
# dataframe of data/5367.csv is read, it is the 831th one
# dataframe of data/5369.csv is read, it is the 832th one
# dataframe of data/5370.csv is read, it is the 833th one
# dataframe of data/5385.csv is read, it is the 834th one
# dataframe of data/5386.csv is read, it is the 835th one
# dataframe of data/5397.csv is read, it is the 836th one
# dataframe of data/5399.csv is read, it is the 837th one
# dataframe of data/5401.csv is read, it is the 838th one
# dataframe of data/5415.csv is read, it is the 839th one
# dataframe of data/5420.csv is read, it is the 840th one
# dataframe of data/5421.csv is read, it is the 841th one
# dataframe of data/5432.csv is read, it is the 842th one
# dataframe of data/5435.csv is read, it is the 843th one
# dataframe of data/5438.csv is read, it is the 844th one
# dataframe of data/5440.csv is read, it is the 845th one
# dataframe of data/5444.csv is read, it is the 846th one
# dataframe of data/5451.csv is read, it is the 847th one
# dataframe of data/5460.csv is read, it is the 848th one
# dataframe of data/5471.csv is read, it is the 849th one
# dataframe of data/5478.csv is read, it is the 850th one
# dataframe of data/5480.csv is read, it is the 851th one
# dataframe of data/5481.csv is read, it is the 852th one
# dataframe of data/5486.csv is read, it is the 853th one
# dataframe of data/5490.csv is read, it is the 854th one
# dataframe of data/5501.csv is read, it is the 855th one
# dataframe of data/5504.csv is read, it is the 856th one
# dataframe of data/5506.csv is read, it is the 857th one
# dataframe of data/5510.csv is read, it is the 858th one
# dataframe of data/5512.csv is read, it is the 859th one
# ...
# dataframe of data/8178.csv is read, it is the 1282th one
# dataframe of data/8181.csv is read, it is the 1283th one
# dataframe of data/8192.csv is read, it is the 1284th one
# dataframe of data/8194.csv is read, it is the 1285th one
# dataframe of data/8203.csv is read, it is the 1286th one
# dataframe of data/8206.csv is read, it is the 1287th one
# dataframe of data/8227.csv is read, it is the 1288th one
# dataframe of data/8234.csv is read, it is the 1289th one
# dataframe of data/8249.csv is read, it is the 1290th one
# dataframe of data/8250.csv is read, it is the 1291th one
# dataframe of data/8253.csv is read, it is the 1292th one
# dataframe of data/8257.csv is read, it is the 1293th one
# dataframe of data/8262.csv is read, it is the 1294th one
# dataframe of data/8266.csv is read, it is the 1295th one
# dataframe of data/8290.csv is read, it is the 1296th one
# dataframe of data/8297.csv is read, it is the 1297th one
# dataframe of data/8299.csv is read, it is the 1298th one
# dataframe of data/8317.csv is read, it is the 1299th one
# dataframe of data/8324.csv is read, it is the 1300th one
# dataframe of data/8328.csv is read, it is the 1301th one
# dataframe of data/8339.csv is read, it is the 1302th one
# dataframe of data/8346.csv is read, it is the 1303th one
# dataframe of data/8348.csv is read, it is the 1304th one
# dataframe of data/8367.csv is read, it is the 1305th one
# dataframe of data/8370.csv is read, it is the 1306th one
# dataframe of data/8372.csv is read, it is the 1307th one
# dataframe of data/8379.csv is read, it is the 1308th one
# dataframe of data/8403.csv is read, it is the 1309th one
# dataframe of data/8408.csv is read, it is the 1310th one
# dataframe of data/8412.csv is read, it is the 1311th one
# dataframe of data/8418.csv is read, it is the 1312th one
# dataframe of data/8421.csv is read, it is the 1313th one
# dataframe of data/8427.csv is read, it is the 1314th one
# dataframe of data/8430.csv is read, it is the 1315th one
# dataframe of data/8431.csv is read, it is the 1316th one
# dataframe of data/8433.csv is read, it is the 1317th one
# dataframe of data/8443.csv is read, it is the 1318th one
# dataframe of data/8455.csv is read, it is the 1319th one
# dataframe of data/8467.csv is read, it is the 1320th one
# dataframe of data/8472.csv is read, it is the 1321th one
# dataframe of data/8480.csv is read, it is the 1322th one
# dataframe of data/8498.csv is read, it is the 1323th one
# dataframe of data/8502.csv is read, it is the 1324th one
# dataframe of data/8515.csv is read, it is the 1325th one
# dataframe of data/8524.csv is read, it is the 1326th one
# dataframe of data/8534.csv is read, it is the 1327th one
# dataframe of data/8539.csv is read, it is the 1328th one
# dataframe of data/8541.csv is read, it is the 1329th one
# dataframe of data/8546.csv is read, it is the 1330th one
# dataframe of data/8548.csv is read, it is the 1331th one
# dataframe of data/8553.csv is read, it is the 1332th one
# dataframe of data/8563.csv is read, it is the 1333th one
# dataframe of data/8569.csv is read, it is the 1334th one
# dataframe of data/8570.csv is read, it is the 1335th one
# dataframe of data/8572.csv is read, it is the 1336th one
# dataframe of data/8578.csv is read, it is the 1337th one
# dataframe of data/8579.csv is read, it is the 1338th one
# dataframe of data/8588.csv is read, it is the 1339th one
# dataframe of data/8589.csv is read, it is the 1340th one
# dataframe of data/8595.csv is read, it is the 1341th one
# dataframe of data/8608.csv is read, it is the 1342th one
# dataframe of data/8614.csv is read, it is the 1343th one
# dataframe of data/8621.csv is read, it is the 1344th one
# dataframe of data/8626.csv is read, it is the 1345th one
# dataframe of data/8645.csv is read, it is the 1346th one
# dataframe of data/8651.csv is read, it is the 1347th one
# dataframe of data/8653.csv is read, it is the 1348th one
# dataframe of data/8654.csv is read, it is the 1349th one
# dataframe of data/8673.csv is read, it is the 1350th one
# dataframe of data/8675.csv is read, it is the 1351th one
# dataframe of data/8681.csv is read, it is the 1352th one
# dataframe of data/8689.csv is read, it is the 1353th one
# dataframe of data/8691.csv is read, it is the 1354th one
# dataframe of data/8695.csv is read, it is the 1355th one
# dataframe of data/8696.csv is read, it is the 1356th one
# dataframe of data/8701.csv is read, it is the 1357th one
# dataframe of data/8713.csv is read, it is the 1358th one
# dataframe of data/8724.csv is read, it is the 1359th one
# dataframe of data/8729.csv is read, it is the 1360th one
# dataframe of data/8748.csv is read, it is the 1361th one
# dataframe of data/8754.csv is read, it is the 1362th one
# dataframe of data/8765.csv is read, it is the 1363th one
# dataframe of data/8767.csv is read, it is the 1364th one
# dataframe of data/8775.csv is read, it is the 1365th one
# dataframe of data/8777.csv is read, it is the 1366th one
# dataframe of data/8787.csv is read, it is the 1367th one
# dataframe of data/8795.csv is read, it is the 1368th one
# dataframe of data/8813.csv is read, it is the 1369th one
# dataframe of data/8815.csv is read, it is the 1370th one
# dataframe of data/8817.csv is read, it is the 1371th one
# dataframe of data/8836.csv is read, it is the 1372th one
# dataframe of data/8843.csv is read, it is the 1373th one
# dataframe of data/8846.csv is read, it is the 1374th one
# dataframe of data/8848.csv is read, it is the 1375th one
# dataframe of data/8858.csv is read, it is the 1376th one
# dataframe of data/8873.csv is read, it is the 1377th one
# dataframe of data/8877.csv is read, it is the 1378th one
# dataframe of data/8879.csv is read, it is the 1379th one
# dataframe of data/8890.csv is read, it is the 1380th one
# dataframe of data/8893.csv is read, it is the 1381th one
# dataframe of data/8897.csv is read, it is the 1382th one
# dataframe of data/8905.csv is read, it is the 1383th one
# dataframe of data/8938.csv is read, it is the 1384th one
# dataframe of data/8944.csv is read, it is the 1385th one
# dataframe of data/8971.csv is read, it is the 1386th one
# dataframe of data/8978.csv is read, it is the 1387th one
# dataframe of data/8979.csv is read, it is the 1388th one
# dataframe of data/8980.csv is read, it is the 1389th one
# dataframe of data/8988.csv is read, it is the 1390th one
# dataframe of data/8998.csv is read, it is the 1391th one
# dataframe of data/9003.csv is read, it is the 1392th one
# dataframe of data/9015.csv is read, it is the 1393th one
# dataframe of data/9019.csv is read, it is the 1394th one
# dataframe of data/9029.csv is read, it is the 1395th one
# dataframe of data/9030.csv is read, it is the 1396th one
# dataframe of data/9035.csv is read, it is the 1397th one
# dataframe of data/9036.csv is read, it is the 1398th one
# dataframe of data/9046.csv is read, it is the 1399th one
# dataframe of data/9052.csv is read, it is the 1400th one
# dataframe of data/9058.csv is read, it is the 1401th one
# dataframe of data/9061.csv is read, it is the 1402th one
# dataframe of data/9068.csv is read, it is the 1403th one
# dataframe of data/9073.csv is read, it is the 1404th one
# dataframe of data/9082.csv is read, it is the 1405th one
# dataframe of data/9088.csv is read, it is the 1406th one
# dataframe of data/9092.csv is read, it is the 1407th one
# dataframe of data/9093.csv is read, it is the 1408th one
# dataframe of data/9097.csv is read, it is the 1409th one
# dataframe of data/9112.csv is read, it is the 1410th one
# dataframe of data/9119.csv is read, it is the 1411th one
# dataframe of data/9131.csv is read, it is the 1412th one
# dataframe of data/9144.csv is read, it is the 1413th one
# dataframe of data/9159.csv is read, it is the 1414th one
# dataframe of data/9165.csv is read, it is the 1415th one
# dataframe of data/9179.csv is read, it is the 1416th one
# dataframe of data/9188.csv is read, it is the 1417th one
# dataframe of data/9190.csv is read, it is the 1418th one
# dataframe of data/9195.csv is read, it is the 1419th one
# dataframe of data/9202.csv is read, it is the 1420th one
# dataframe of data/9204.csv is read, it is the 1421th one
# dataframe of data/9206.csv is read, it is the 1422th one
# dataframe of data/9211.csv is read, it is the 1423th one
# dataframe of data/9217.csv is read, it is the 1424th one
# dataframe of data/9219.csv is read, it is the 1425th one
# dataframe of data/9220.csv is read, it is the 1426th one
# dataframe of data/9222.csv is read, it is the 1427th one
# dataframe of data/9230.csv is read, it is the 1428th one
# dataframe of data/9238.csv is read, it is the 1429th one
# dataframe of data/9247.csv is read, it is the 1430th one
# dataframe of data/9255.csv is read, it is the 1431th one
# dataframe of data/9263.csv is read, it is the 1432th one
# dataframe of data/9265.csv is read, it is the 1433th one
# dataframe of data/9273.csv is read, it is the 1434th one
# dataframe of data/9275.csv is read, it is the 1435th one
# dataframe of data/9276.csv is read, it is the 1436th one
# dataframe of data/9279.csv is read, it is the 1437th one
# dataframe of data/9289.csv is read, it is the 1438th one
# dataframe of data/9296.csv is read, it is the 1439th one
# dataframe of data/9301.csv is read, it is the 1440th one
# dataframe of data/9318.csv is read, it is the 1441th one
# dataframe of data/9323.csv is read, it is the 1442th one
# dataframe of data/9326.csv is read, it is the 1443th one
# dataframe of data/9328.csv is read, it is the 1444th one
# dataframe of data/9329.csv is read, it is the 1445th one
# dataframe of data/9341.csv is read, it is the 1446th one
# dataframe of data/9343.csv is read, it is the 1447th one
# dataframe of data/9344.csv is read, it is the 1448th one
# dataframe of data/9350.csv is read, it is the 1449th one
# dataframe of data/9352.csv is read, it is the 1450th one
# dataframe of data/9367.csv is read, it is the 1451th one
# dataframe of data/9369.csv is read, it is the 1452th one
# dataframe of data/9372.csv is read, it is the 1453th one
# dataframe of data/9379.csv is read, it is the 1454th one
# dataframe of data/9390.csv is read, it is the 1455th one
# dataframe of data/9404.csv is read, it is the 1456th one
# dataframe of data/9419.csv is read, it is the 1457th one
# dataframe of data/9420.csv is read, it is the 1458th one
# dataframe of data/9428.csv is read, it is the 1459th one
# dataframe of data/9435.csv is read, it is the 1460th one
# dataframe of data/9450.csv is read, it is the 1461th one
# dataframe of data/9453.csv is read, it is the 1462th one
# dataframe of data/9454.csv is read, it is the 1463th one
# dataframe of data/9463.csv is read, it is the 1464th one
# dataframe of data/9467.csv is read, it is the 1465th one
# dataframe of data/9470.csv is read, it is the 1466th one
# dataframe of data/9494.csv is read, it is the 1467th one
# dataframe of data/9499.csv is read, it is the 1468th one
# dataframe of data/9505.csv is read, it is the 1469th one
# dataframe of data/9508.csv is read, it is the 1470th one
# dataframe of data/9515.csv is read, it is the 1471th one
# dataframe of data/9533.csv is read, it is the 1472th one
# dataframe of data/9553.csv is read, it is the 1473th one
# dataframe of data/9556.csv is read, it is the 1474th one
# dataframe of data/9559.csv is read, it is the 1475th one
# dataframe of data/9573.csv is read, it is the 1476th one
# dataframe of data/9584.csv is read, it is the 1477th one
# dataframe of data/9585.csv is read, it is the 1478th one
# dataframe of data/9589.csv is read, it is the 1479th one
# dataframe of data/9599.csv is read, it is the 1480th one
# dataframe of data/9604.csv is read, it is the 1481th one
# dataframe of data/9610.csv is read, it is the 1482th one
# dataframe of data/9624.csv is read, it is the 1483th one
# dataframe of data/9660.csv is read, it is the 1484th one
# dataframe of data/9672.csv is read, it is the 1485th one
# dataframe of data/9681.csv is read, it is the 1486th one
# dataframe of data/9691.csv is read, it is the 1487th one
# dataframe of data/9694.csv is read, it is the 1488th one
# dataframe of data/9699.csv is read, it is the 1489th one
# dataframe of data/9700.csv is read, it is the 1490th one
# dataframe of data/9701.csv is read, it is the 1491th one
# dataframe of data/9703.csv is read, it is the 1492th one
# dataframe of data/9706.csv is read, it is the 1493th one
# dataframe of data/9714.csv is read, it is the 1494th one
# dataframe of data/9719.csv is read, it is the 1495th one
# dataframe of data/9729.csv is read, it is the 1496th one
# dataframe of data/9739.csv is read, it is the 1497th one
# dataframe of data/9742.csv is read, it is the 1498th one
# dataframe of data/9751.csv is read, it is the 1499th one
# dataframe of data/9766.csv is read, it is the 1500th one
# dataframe of data/9767.csv is read, it is the 1501th one
# dataframe of data/9770.csv is read, it is the 1502th one
# dataframe of data/9773.csv is read, it is the 1503th one
# dataframe of data/9774.csv is read, it is the 1504th one
# dataframe of data/9778.csv is read, it is the 1505th one
# dataframe of data/9784.csv is read, it is the 1506th one
# dataframe of data/9797.csv is read, it is the 1507th one
# dataframe of data/9798.csv is read, it is the 1508th one
# dataframe of data/9802.csv is read, it is the 1509th one
# dataframe of data/9805.csv is read, it is the 1510th one
# dataframe of data/9809.csv is read, it is the 1511th one
# dataframe of data/9814.csv is read, it is the 1512th one
# dataframe of data/9815.csv is read, it is the 1513th one
# dataframe of data/9818.csv is read, it is the 1514th one
# dataframe of data/9820.csv is read, it is the 1515th one
# dataframe of data/9838.csv is read, it is the 1516th one
# dataframe of data/9840.csv is read, it is the 1517th one
# dataframe of data/9844.csv is read, it is the 1518th one
# dataframe of data/9858.csv is read, it is the 1519th one
# dataframe of data/9859.csv is read, it is the 1520th one
# dataframe of data/9860.csv is read, it is the 1521th one
# dataframe of data/9865.csv is read, it is the 1522th one
# dataframe of data/9866.csv is read, it is the 1523th one
# dataframe of data/9868.csv is read, it is the 1524th one
# dataframe of data/9870.csv is read, it is the 1525th one
# dataframe of data/9871.csv is read, it is the 1526th one
# dataframe of data/9879.csv is read, it is the 1527th one
# dataframe of data/9884.csv is read, it is the 1528th one
# dataframe of data/9888.csv is read, it is the 1529th one
# dataframe of data/9897.csv is read, it is the 1530th one
# dataframe of data/9901.csv is read, it is the 1531th one
# dataframe of data/9913.csv is read, it is the 1532th one
# dataframe of data/9922.csv is read, it is the 1533th one
# dataframe of data/9930.csv is read, it is the 1534th one
# dataframe of data/9939.csv is read, it is the 1535th one
# dataframe of data/9941.csv is read, it is the 1536th one
# dataframe of data/9947.csv is read, it is the 1537th one
# dataframe of data/9954.csv is read, it is the 1538th one
# dataframe of data/9956.csv is read, it is the 1539th one
# dataframe of data/9963.csv is read, it is the 1540th one
# dataframe of data/9991.csv is read, it is the 1541th one
# dataframe of data/9995.csv is read, it is the 1542th one
# dataframe of data/9999.csv is read, it is the 1543th one
#    Unnamed: 0                       time  sh_id       ori_r       ori_p  \
# 0           0 2024-01-01 00:00:00.000000  rpi02  269.545681  356.749989
# 1           1 2024-01-01 00:00:00.021664  rpi04    0.882781  356.174715
# 2           2 2024-01-01 00:00:00.032167  rpi01  353.893131  355.246462
# 3           3 2024-01-01 00:00:00.051721  rpi03  170.776873   88.503023
# 4           4 2024-01-01 00:00:00.072409  rpi04    0.840144  356.154963
#
#         ori_y     gyr_x     gyr_y     gyr_z     acc_x     acc_y     acc_z  \
# 0  125.587303 -0.001464 -0.002130  0.001607  0.033458 -0.996745 -0.014221
# 1  151.752965 -0.003406  0.000361  0.005360  0.079280  0.030349  0.973569
# 2  133.680558 -0.004923  0.002182  0.000213  0.084856 -0.099385  0.981367
# 3  355.694066  0.000246 -0.001458 -0.001224 -0.995241 -0.009167 -0.029647
# 4  151.629353  0.017057 -0.001167 -0.012965  0.076128 -0.008925  0.979418
#
#     seconds
# 0  0.000000
# 1  0.021664
# 2  0.032167
# 3  0.051721
# 4  0.072409
# Label for file '0025': 0

# %% [markdown]
# We have two dictionaries that store the labels and data for files:
#
# - `labels_dict`: This dictionary uses four-digit filenames (e.g., `'0025'`) as keys, with each key corresponding to the label of a specific file. By using the filename as a key, you can access the label of any particular file. For instance, `labels_dict['0025']` provides access to the label of the file `'0025.csv'`.
#
# - `data_frames`: Similarly, this dictionary also uses four-digit filenames as keys (e.g., `'0025'`), where each key corresponds to a DataFrame that contains the data from the associated CSV file. For example, `data_frames['0025']` will give you the data associated with the file `'0025.csv'`.
